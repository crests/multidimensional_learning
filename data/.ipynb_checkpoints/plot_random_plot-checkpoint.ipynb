# %%
# first data analysis, common among many types of datas

## import library
import pandas as pd
from scipy import stats
import seaborn as sns
from ptitprince import PtitPrince as pt
import matplotlib.pyplot as plt

## set param
#sns.set(style="darkgrid")
#sns.set_style("white")
sns.set(style="whitegrid",font_scale=2)

# %%
for i in range(50):
    plt.figure()
    data = pd.read_csv("randomArr/randomArr_"+ str(i)+ ".csv", sep=",", header=None)
    plt.plot(data.transpose())
    plt.title(str(i))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
data = pd.read_csv("randomArr/randomArr_0.csv", sep=",", header=None)
#print(data.transpose()[0])
#sns.lineplot(data.transpose()[0])
plt.plot(data.transpose())
# Out:
# 0     72
# 1     71
# 2     70
# 3     69
# 4     68
#       ..
# 95    66
# 96    67
# 97    68
# 98    68
# 99    69
# Name: 0, Length: 100, dtype: int64
# ...

# %%
data11 = pd.read_csv("randomArr/randomArr_11+.csv", sep=",", header=None).transpose()
plt.plot(data11)
plt.title("11")

print(data11)
# Out:
#      0   1   2
# 0   51  73  73
# 1   47  79  77
# 2   51  77  83
# 3   45  72  82
# 4   44  72  76
# ..  ..  ..  ..
# 95  77  56  57
# 96  80  53  55
# 97  76  54  55
# 98  80  51  57
# 99  75  49  60
#
# [100 rows x 3 columns]

# %%
prob11 = data11;
for i in range(100):
    over = pd.e^data11[i][0]  + pd.e^data11[i][1] + pd.e^data11[i][2]
    for j in range(3):
        prob11[i][j] = pd.e^data11[i][j]/over
